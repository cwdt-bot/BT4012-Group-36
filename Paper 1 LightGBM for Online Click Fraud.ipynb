# %% [markdown]
# # Import Libararies

# %%
# need the latest version of lightgbm 3.3.1
# !pip install lightgbm --upgrade
# Out:
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.7/dist-packages (2.2.3)
# Collecting lightgbm
#   Downloading lightgbm-3.3.1-py3-none-manylinux1_x86_64.whl (2.0 MB)
#      |████████████████████████████████| 2.0 MB 34.7 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from lightgbm) (1.19.5)
# Requirement already satisfied: scikit-learn!=0.22.0 in /usr/local/lib/python3.7/dist-packages (from lightgbm) (0.22.2.post1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from lightgbm) (1.4.1)
# Requirement already satisfied: wheel in /usr/local/lib/python3.7/dist-packages (from lightgbm) (0.37.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn!=0.22.0->lightgbm) (1.1.0)
# Installing collected packages: lightgbm
#   Attempting uninstall: lightgbm
#     Found existing installation: lightgbm 2.2.3
#     Uninstalling lightgbm-2.2.3:
#       Successfully uninstalled lightgbm-2.2.3
# Successfully installed lightgbm-3.3.1

# %%
import lightgbm as lgb
import pandas as pd
import numpy as np
import datetime
from sklearn.model_selection import train_test_split
from sklearn import metrics
import datetime
print(lgb.__version__)
# Out:
# 3.3.1

# %%
pip install pipreqs
# Out:
# Collecting pipreqs
#   Downloading pipreqs-0.4.11-py2.py3-none-any.whl (32 kB)
# Requirement already satisfied: docopt in /usr/local/lib/python3.7/dist-packages (from pipreqs) (0.6.2)
# Collecting yarg
#   Downloading yarg-0.1.9-py2.py3-none-any.whl (19 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from yarg->pipreqs) (2.23.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->yarg->pipreqs) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->yarg->pipreqs) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->yarg->pipreqs) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->yarg->pipreqs) (1.24.3)
# Installing collected packages: yarg, pipreqs
# Successfully installed pipreqs-0.4.11 yarg-0.1.9

# %% [markdown]
# # Dataset 1: Click Fraud Data

# %% [markdown]
# The original text here https://ibimapublishing.com/articles/JIACS/2019/263928/

# %% [markdown]
# ## Importing Data

# %%
# dataset taken from https://www.kaggle.com/c/talkingdata-adtracking-fraud-detection/data?select=train.csv
# !gdown --id 1-6p65jg0jIK3LsjK4PBAcGIHx85lHMyW
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1-6p65jg0jIK3LsjK4PBAcGIHx85lHMyW
# To: /content/combined.csv
# 100% 79.9M/79.9M [00:00<00:00, 153MB/s]

# %% [markdown]
# Since the dataset is large, we decided to download part of the dataset and store it on gdrive for easy of running this notebook. Note that as detailed in our report, we decided to take all the positive samples and some of the negative samples in a rough 1:2 ratio to do our testing due to the highly imbalanced nature of the dataset

# %%
df = pd.read_csv('combined.csv')
df.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Unnamed: 0      ip  ...      attributed_time  is_attributed
# 0         103  204158  ...  2017-11-07 08:17:19              1
# 1        1504   29692  ...  2017-11-07 10:05:22              1
# 2        1798   64516  ...  2017-11-06 23:40:50              1
# 3        2102  172429  ...  2017-11-07 00:55:29              1
# 4        3056  199085  ...  2017-11-06 23:04:54              1
#
# [5 rows x 9 columns]

# %% [markdown]
# ## LightGBM on Click Fraud Data

# %% [markdown]
# ### Data Preprocessing for LightGBM

# %%
df = df.drop(['Unnamed: 0', 'attributed_time'], axis = 1)
df.head()
# Out:
#        ip  app  device  os  channel           click_time  is_attributed
# 0  204158   35       1  13       21  2017-11-06 15:41:07              1
# 1   29692    9       1  22      215  2017-11-06 16:00:02              1
# 2   64516   35       1  13       21  2017-11-06 16:00:02              1
# 3  172429   35       1  46      274  2017-11-06 16:00:03              1
# 4  199085   35       1  13      274  2017-11-06 16:00:04              1

# %%
def find_day(timestamp):
  timestamp_read = datetime.datetime.fromisoformat(timestamp)
  return  timestamp_read.weekday()

def find_hour(timestamp):
  timestamp_read = datetime.datetime.fromisoformat(timestamp)
  return timestamp_read.hour

# %%
df['day'] = df['click_time'].apply(find_day)
df['hour'] = df['click_time'].apply(find_hour)
df.drop('click_time', inplace = True, axis = 1)
df.head()
# Out:
#        ip  app  device  os  channel  is_attributed  day  hour
# 0  204158   35       1  13       21              1    0    15
# 1   29692    9       1  22      215              1    0    16
# 2   64516   35       1  13       21              1    0    16
# 3  172429   35       1  46      274              1    0    16
# 4  199085   35       1  13      274              1    0    16

# %%
labels = df['is_attributed']
df = df.drop('is_attributed', axis = 1)
df.head()
# Out:
#        ip  app  device  os  channel  day  hour
# 0  204158   35       1  13       21    0    15
# 1   29692    9       1  22      215    0    16
# 2   64516   35       1  13       21    0    16
# 3  172429   35       1  46      274    0    16
# 4  199085   35       1  13      274    0    16

# %%
data = lgb.Dataset(df, label = labels, categorical_feature=list(df.columns),free_raw_data=False)

# %% [markdown]
# ### Running LightGBM

# %%
# these params were specified in the paper 
params = {
    'learning_rate': 0.2,
    'max_depth': 3,
    'num_leaves': 7,
    'min_child_samples': 100,
    'min_child_weight': 0,
    'subsample': 0.7,
    'subsample_freq': 1,
    'colsample_bytree': 0.9,
    'scale_pos_weight': 200,
    'metric': ['auc', 'cross_entropy', 'l2'],
    'objective': 'binary'
}

# %%
start = datetime.datetime.now()
eval = lgb.cv(params=params, train_set = data,nfold=5, verbose_eval = 10, early_stopping_rounds = 100, return_cvbooster=True)
time_taken = datetime.datetime.now() - start
print(time_taken)
# Out:
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:577: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/basic.py:2065: UserWarning: Using categorical_feature in Dataset.
#   _log_warning('Using categorical_feature in Dataset.')
# [LightGBM] [Info] Number of positive: 365476, number of negative: 806629
# [LightGBM] [Info] [cross_entropy:Init]: (metric) labels passed interval [0, 1] check
# [LightGBM] [Info] [cross_entropy:Init]: sum-of-weights = 1172105.000000
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.057487 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 17093
# [LightGBM] [Info] Number of data points in the train set: 1172105, number of used features: 7
# [LightGBM] [Info] [cross_entropy:Init]: (metric) labels passed interval [0, 1] check
# [LightGBM] [Info] [cross_entropy:Init]: sum-of-weights = 293027.000000
# [LightGBM] [Info] Number of positive: 365477, number of negative: 806628
# [LightGBM] [Info] [cross_entropy:Init]: (metric) labels passed interval [0, 1] check
# [LightGBM] [Info] [cross_entropy:Init]: sum-of-weights = 1172105.000000
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.055157 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 17093
# [LightGBM] [Info] Number of data points in the train set: 1172105, number of used features: 7
# [LightGBM] [Info] [cross_entropy:Init]: (metric) labels passed interval [0, 1] check
# [LightGBM] [Info] [cross_entropy:Init]: sum-of-weights = 293027.000000
# [LightGBM] [Info] Number of positive: 365477, number of negative: 806629
# [LightGBM] [Info] [cross_entropy:Init]: (metric) labels passed interval [0, 1] check
# [LightGBM] [Info] [cross_entropy:Init]: sum-of-weights = 1172106.000000
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.055502 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 17093
# [LightGBM] [Info] Number of data points in the train set: 1172106, number of used features: 7
# [LightGBM] [Info] [cross_entropy:Init]: (metric) labels passed interval [0, 1] check
# [LightGBM] [Info] [cross_entropy:Init]: sum-of-weights = 293026.000000
# [LightGBM] [Info] Number of positive: 365477, number of negative: 806629
# [LightGBM] [Info] [cross_entropy:Init]: (metric) labels passed interval [0, 1] check
# [LightGBM] [Info] [cross_entropy:Init]: sum-of-weights = 1172106.000000
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.056154 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 17093
# [LightGBM] [Info] Number of data points in the train set: 1172106, number of used features: 7
# [LightGBM] [Info] [cross_entropy:Init]: (metric) labels passed interval [0, 1] check
# [LightGBM] [Info] [cross_entropy:Init]: sum-of-weights = 293026.000000
# [LightGBM] [Info] Number of positive: 365477, number of negative: 806629
# [LightGBM] [Info] [cross_entropy:Init]: (metric) labels passed interval [0, 1] check
# [LightGBM] [Info] [cross_entropy:Init]: sum-of-weights = 1172106.000000
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.056327 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 17093
# [LightGBM] [Info] Number of data points in the train set: 1172106, number of used features: 7
# [LightGBM] [Info] [cross_entropy:Init]: (metric) labels passed interval [0, 1] check
# [LightGBM] [Info] [cross_entropy:Init]: sum-of-weights = 293026.000000
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.311812 -> initscore=-0.791663
# [LightGBM] [Info] Start training from score -0.791663
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.311813 -> initscore=-0.791659
# [LightGBM] [Info] Start training from score -0.791659
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:620: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.311812 -> initscore=-0.791660
# [LightGBM] [Info] Start training from score -0.791660
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.311812 -> initscore=-0.791660
# [LightGBM] [Info] Start training from score -0.791660
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.311812 -> initscore=-0.791660
# [LightGBM] [Info] Start training from score -0.791660
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [10]	cv_agg's auc: 0.999061 + 7.6901e-05	cv_agg's cross_entropy: 0.190919 + 0.00272429	cv_agg's l2: 0.0362355 + 0.00104985
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [20]	cv_agg's auc: 0.999365 + 8.31143e-05	cv_agg's cross_entropy: 0.148217 + 0.00238545	cv_agg's l2: 0.0280225 + 0.000626433
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [30]	cv_agg's auc: 0.999428 + 6.71091e-05	cv_agg's cross_entropy: 0.128012 + 0.00265146	cv_agg's l2: 0.0241218 + 0.00067179
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [40]	cv_agg's auc: 0.999443 + 7.02495e-05	cv_agg's cross_entropy: 0.116853 + 0.0024518	cv_agg's l2: 0.022494 + 0.000532216
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [50]	cv_agg's auc: 0.999457 + 6.75982e-05	cv_agg's cross_entropy: 0.109139 + 0.00245913	cv_agg's l2: 0.0212642 + 0.00053324
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [60]	cv_agg's auc: 0.999456 + 5.9539e-05	cv_agg's cross_entropy: 0.101708 + 0.002143	cv_agg's l2: 0.0200593 + 0.000457313
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [70]	cv_agg's auc: 0.999459 + 5.85867e-05	cv_agg's cross_entropy: 0.0972739 + 0.00209341	cv_agg's l2: 0.0194091 + 0.000425869
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [80]	cv_agg's auc: 0.999463 + 6.17957e-05	cv_agg's cross_entropy: 0.0927891 + 0.0022531	cv_agg's l2: 0.0184699 + 0.000473767
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [90]	cv_agg's auc: 0.999462 + 6.15015e-05	cv_agg's cross_entropy: 0.0896933 + 0.00273929	cv_agg's l2: 0.0179107 + 0.000622006
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [100]	cv_agg's auc: 0.999469 + 6.00846e-05	cv_agg's cross_entropy: 0.0870683 + 0.00236211	cv_agg's l2: 0.0174536 + 0.000467027
# 0:01:25.195532

# %% [markdown]
# ### Feature Importance

# %%
def getfeatureimpt(eval): 
  feature_importance = {}
  c = 1
  for b in eval['cvbooster'].boosters:
    feature_importance[c] = {k:v for k,v in zip(b.feature_name(), b.feature_importance(importance_type='gain'))}
    c+=1
  fi = pd.DataFrame(feature_importance)
  means = pd.DataFrame(fi.mean(axis = 1))
  means.columns = ['mean']
  means.sort_values(by = 'mean', inplace = True, ascending=False)
  means['perc'] = means['mean']/means['mean'].sum()
  return means

# %%
# mean refers to mean information gain, perc is the % of total information gain for the feature
features = getfeatureimpt(eval)
features
# Out:
#                  mean      perc
# hour     3.294346e+06  0.349809
# day      2.341006e+06  0.248579
# channel  1.490126e+06  0.158229
# app      1.422214e+06  0.151017
# ip       6.873885e+05  0.072990
# os       1.723540e+05  0.018301
# device   1.011826e+04  0.001074

# %% [markdown]
# ## XGBoost on Click Fraud Data

# %%
from xgboost import XGBClassifier
import pandas as pd
import datetime
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import gc
import numpy as np

# %% [markdown]
# ### XGBoost Data Preparation

# %%
df = pd.read_csv('combined.csv')
df_process = df.drop(['Unnamed: 0', 'attributed_time'], axis = 1)
df_process.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#        ip  app  device  os  channel           click_time  is_attributed
# 0  204158   35       1  13       21  2017-11-06 15:41:07              1
# 1   29692    9       1  22      215  2017-11-06 16:00:02              1
# 2   64516   35       1  13       21  2017-11-06 16:00:02              1
# 3  172429   35       1  46      274  2017-11-06 16:00:03              1
# 4  199085   35       1  13      274  2017-11-06 16:00:04              1

# %%
df_process['hour'] = df_process['click_time'].apply(find_hour)
df_process['day'] =  df_process['click_time'].apply(find_day)

# %%
df_process = df_process.drop(['click_time', 'ip'], axis = 1)

# %%
for col in df_process.columns:
  df_process[col] = df_process[col].astype('category')

df_process.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465132 entries, 0 to 1465131
# Data columns (total 7 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   app            1465132 non-null  category
#  1   device         1465132 non-null  category
#  2   os             1465132 non-null  category
#  3   channel        1465132 non-null  category
#  4   is_attributed  1465132 non-null  category
#  5   hour           1465132 non-null  category
#  6   day            1465132 non-null  category
# dtypes: category(7)
# memory usage: 15.5 MB

# %%
df_process_X = df_process.drop('is_attributed', axis = 1)
x_train, x_val, y_train, y_val = train_test_split(df_process_X, df_process['is_attributed'], test_size=0.33, random_state=42)

# %% [markdown]
# ### Train XGBoost

# %%
xgbmodel = XGBClassifier(objective='binary:logistic',  n_estimators = 1000, booster = 'gbtree', eval_metric = ['auc', 'logloss'])
start = datetime.datetime.now()
xgbmodel.fit(x_train.values, y_train.values, eval_set = [(x_val.values, y_val.values)], early_stopping_rounds = 20)
time_taken = datetime.datetime.now() - start
print(time_taken)
# Out:
# [0]	validation_0-auc:0.996676	validation_0-logloss:0.597095
# Multiple eval metrics have been passed: 'validation_0-logloss' will be used for early stopping.
#
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [1]	validation_0-auc:0.996676	validation_0-logloss:0.519941
# [2]	validation_0-auc:0.996676	validation_0-logloss:0.455719
# [3]	validation_0-auc:0.998345	validation_0-logloss:0.404203
# [4]	validation_0-auc:0.998345	validation_0-logloss:0.357222
# [5]	validation_0-auc:0.998345	validation_0-logloss:0.316317
# [6]	validation_0-auc:0.998345	validation_0-logloss:0.28373
# [7]	validation_0-auc:0.998345	validation_0-logloss:0.253091
# [8]	validation_0-auc:0.998345	validation_0-logloss:0.226941
# [9]	validation_0-auc:0.998345	validation_0-logloss:0.203752
# [10]	validation_0-auc:0.998345	validation_0-logloss:0.183313
# [11]	validation_0-auc:0.998345	validation_0-logloss:0.164972
# [12]	validation_0-auc:0.998345	validation_0-logloss:0.14837
# [13]	validation_0-auc:0.998345	validation_0-logloss:0.134153
# [14]	validation_0-auc:0.998345	validation_0-logloss:0.121801
# [15]	validation_0-auc:0.998345	validation_0-logloss:0.110434
# [16]	validation_0-auc:0.998345	validation_0-logloss:0.100205
# [17]	validation_0-auc:0.998345	validation_0-logloss:0.091351
# [18]	validation_0-auc:0.998345	validation_0-logloss:0.083329
# [19]	validation_0-auc:0.998345	validation_0-logloss:0.076237
# [20]	validation_0-auc:0.998345	validation_0-logloss:0.069281
# [21]	validation_0-auc:0.998345	validation_0-logloss:0.063522
# [22]	validation_0-auc:0.998345	validation_0-logloss:0.058682
# [23]	validation_0-auc:0.998345	validation_0-logloss:0.053855
# [24]	validation_0-auc:0.998345	validation_0-logloss:0.049826
# [25]	validation_0-auc:0.998345	validation_0-logloss:0.046086
# [26]	validation_0-auc:0.998345	validation_0-logloss:0.042624
# [27]	validation_0-auc:0.998345	validation_0-logloss:0.039644
# [28]	validation_0-auc:0.998345	validation_0-logloss:0.036947
# [29]	validation_0-auc:0.998677	validation_0-logloss:0.034177
# [30]	validation_0-auc:0.998704	validation_0-logloss:0.031833
# [31]	validation_0-auc:0.998706	validation_0-logloss:0.029481
# [32]	validation_0-auc:0.998707	validation_0-logloss:0.027471
# [33]	validation_0-auc:0.998707	validation_0-logloss:0.025826
# [34]	validation_0-auc:0.998707	validation_0-logloss:0.024275
# [35]	validation_0-auc:0.998707	validation_0-logloss:0.022889
# [36]	validation_0-auc:0.998724	validation_0-logloss:0.021559
# [37]	validation_0-auc:0.998724	validation_0-logloss:0.020506
# [38]	validation_0-auc:0.998727	validation_0-logloss:0.019472
# [39]	validation_0-auc:0.998727	validation_0-logloss:0.018449
# [40]	validation_0-auc:0.998728	validation_0-logloss:0.017733
# [41]	validation_0-auc:0.998727	validation_0-logloss:0.017026
# [42]	validation_0-auc:0.998728	validation_0-logloss:0.016288
# [43]	validation_0-auc:0.998728	validation_0-logloss:0.015622
# [44]	validation_0-auc:0.998727	validation_0-logloss:0.015166
# [45]	validation_0-auc:0.998727	validation_0-logloss:0.01464
# [46]	validation_0-auc:0.998727	validation_0-logloss:0.014206
# [47]	validation_0-auc:0.998727	validation_0-logloss:0.013797
# [48]	validation_0-auc:0.998727	validation_0-logloss:0.013352
# [49]	validation_0-auc:0.998728	validation_0-logloss:0.013059
# [50]	validation_0-auc:0.998729	validation_0-logloss:0.012778
# [51]	validation_0-auc:0.998729	validation_0-logloss:0.01246
# [52]	validation_0-auc:0.998729	validation_0-logloss:0.012258
# [53]	validation_0-auc:0.998729	validation_0-logloss:0.011999
# [54]	validation_0-auc:0.99873	validation_0-logloss:0.011813
# [55]	validation_0-auc:0.99873	validation_0-logloss:0.011658
# [56]	validation_0-auc:0.99873	validation_0-logloss:0.01148
# [57]	validation_0-auc:0.99873	validation_0-logloss:0.011347
# [58]	validation_0-auc:0.99873	validation_0-logloss:0.011187
# [59]	validation_0-auc:0.99873	validation_0-logloss:0.011073
# [60]	validation_0-auc:0.998731	validation_0-logloss:0.010982
# [61]	validation_0-auc:0.998731	validation_0-logloss:0.010816
# [62]	validation_0-auc:0.998731	validation_0-logloss:0.010745
# [63]	validation_0-auc:0.998731	validation_0-logloss:0.010585
# [64]	validation_0-auc:0.998909	validation_0-logloss:0.010529
# [65]	validation_0-auc:0.998909	validation_0-logloss:0.010468
# [66]	validation_0-auc:0.998909	validation_0-logloss:0.010396
# [67]	validation_0-auc:0.998909	validation_0-logloss:0.010348
# [68]	validation_0-auc:0.998909	validation_0-logloss:0.010304
# [69]	validation_0-auc:0.998938	validation_0-logloss:0.010284
# [70]	validation_0-auc:0.998938	validation_0-logloss:0.010237
# [71]	validation_0-auc:0.998938	validation_0-logloss:0.01014
# [72]	validation_0-auc:0.998938	validation_0-logloss:0.010135
# [73]	validation_0-auc:0.998938	validation_0-logloss:0.010109
# [74]	validation_0-auc:0.998938	validation_0-logloss:0.010088
# [75]	validation_0-auc:0.998938	validation_0-logloss:0.010058
# [76]	validation_0-auc:0.998935	validation_0-logloss:0.009971
# [77]	validation_0-auc:0.998935	validation_0-logloss:0.009955
# [78]	validation_0-auc:0.998935	validation_0-logloss:0.009901
# [79]	validation_0-auc:0.99894	validation_0-logloss:0.009873
# [80]	validation_0-auc:0.99894	validation_0-logloss:0.009859
# [81]	validation_0-auc:0.998936	validation_0-logloss:0.009798
# [82]	validation_0-auc:0.99895	validation_0-logloss:0.009749
# [83]	validation_0-auc:0.998952	validation_0-logloss:0.009735
# [84]	validation_0-auc:0.998946	validation_0-logloss:0.009717
# [85]	validation_0-auc:0.998948	validation_0-logloss:0.009666
# [86]	validation_0-auc:0.99895	validation_0-logloss:0.009645
# [87]	validation_0-auc:0.998954	validation_0-logloss:0.009618
# [88]	validation_0-auc:0.998959	validation_0-logloss:0.009598
# [89]	validation_0-auc:0.998959	validation_0-logloss:0.009581
# [90]	validation_0-auc:0.99896	validation_0-logloss:0.009566
# [91]	validation_0-auc:0.998962	validation_0-logloss:0.009537
# [92]	validation_0-auc:0.998962	validation_0-logloss:0.009506
# [93]	validation_0-auc:0.998963	validation_0-logloss:0.009492
# [94]	validation_0-auc:0.99897	validation_0-logloss:0.009471
# [95]	validation_0-auc:0.998973	validation_0-logloss:0.009461
# [96]	validation_0-auc:0.998973	validation_0-logloss:0.009448
# [97]	validation_0-auc:0.998973	validation_0-logloss:0.009419
# [98]	validation_0-auc:0.998974	validation_0-logloss:0.00939
# [99]	validation_0-auc:0.999028	validation_0-logloss:0.009366
# [100]	validation_0-auc:0.999029	validation_0-logloss:0.009357
# [101]	validation_0-auc:0.99903	validation_0-logloss:0.009328
# [102]	validation_0-auc:0.999047	validation_0-logloss:0.00932
# [103]	validation_0-auc:0.999041	validation_0-logloss:0.009306
# [104]	validation_0-auc:0.999106	validation_0-logloss:0.009281
# [105]	validation_0-auc:0.999107	validation_0-logloss:0.009264
# [106]	validation_0-auc:0.999103	validation_0-logloss:0.009259
# [107]	validation_0-auc:0.999117	validation_0-logloss:0.009245
# [108]	validation_0-auc:0.999117	validation_0-logloss:0.009236
# [109]	validation_0-auc:0.999117	validation_0-logloss:0.009233
# [110]	validation_0-auc:0.999117	validation_0-logloss:0.009209
# [111]	validation_0-auc:0.999116	validation_0-logloss:0.009201
# [112]	validation_0-auc:0.999121	validation_0-logloss:0.009192
# [113]	validation_0-auc:0.99912	validation_0-logloss:0.009181
# [114]	validation_0-auc:0.99912	validation_0-logloss:0.009176
# [115]	validation_0-auc:0.999129	validation_0-logloss:0.009166
# [116]	validation_0-auc:0.999143	validation_0-logloss:0.009117
# [117]	validation_0-auc:0.999145	validation_0-logloss:0.009105
# [118]	validation_0-auc:0.999146	validation_0-logloss:0.009087
# [119]	validation_0-auc:0.999149	validation_0-logloss:0.009079
# [120]	validation_0-auc:0.999154	validation_0-logloss:0.009077
# [121]	validation_0-auc:0.999153	validation_0-logloss:0.009067
# [122]	validation_0-auc:0.999156	validation_0-logloss:0.009056
# [123]	validation_0-auc:0.999155	validation_0-logloss:0.009039
# [124]	validation_0-auc:0.999173	validation_0-logloss:0.009011
# [125]	validation_0-auc:0.999174	validation_0-logloss:0.009005
# [126]	validation_0-auc:0.999191	validation_0-logloss:0.008983
# [127]	validation_0-auc:0.999193	validation_0-logloss:0.008971
# [128]	validation_0-auc:0.999193	validation_0-logloss:0.008969
# [129]	validation_0-auc:0.999195	validation_0-logloss:0.008963
# [130]	validation_0-auc:0.999217	validation_0-logloss:0.008919
# [131]	validation_0-auc:0.999221	validation_0-logloss:0.008912
# [132]	validation_0-auc:0.999226	validation_0-logloss:0.008897
# [133]	validation_0-auc:0.999226	validation_0-logloss:0.008892
# [134]	validation_0-auc:0.999227	validation_0-logloss:0.008882
# [135]	validation_0-auc:0.999233	validation_0-logloss:0.008876
# [136]	validation_0-auc:0.999233	validation_0-logloss:0.008871
# [137]	validation_0-auc:0.999233	validation_0-logloss:0.008866
# [138]	validation_0-auc:0.999233	validation_0-logloss:0.008866
# [139]	validation_0-auc:0.99923	validation_0-logloss:0.008864
# [140]	validation_0-auc:0.999236	validation_0-logloss:0.008848
# [141]	validation_0-auc:0.999233	validation_0-logloss:0.008836
# [142]	validation_0-auc:0.999238	validation_0-logloss:0.008831
# [143]	validation_0-auc:0.999245	validation_0-logloss:0.008816
# [144]	validation_0-auc:0.999249	validation_0-logloss:0.008803
# [145]	validation_0-auc:0.999248	validation_0-logloss:0.008794
# [146]	validation_0-auc:0.999249	validation_0-logloss:0.008792
# [147]	validation_0-auc:0.999253	validation_0-logloss:0.008775
# [148]	validation_0-auc:0.999253	validation_0-logloss:0.008772
# [149]	validation_0-auc:0.99925	validation_0-logloss:0.008764
# [150]	validation_0-auc:0.999249	validation_0-logloss:0.008753
# [151]	validation_0-auc:0.999256	validation_0-logloss:0.008737
# [152]	validation_0-auc:0.999263	validation_0-logloss:0.008734
# [153]	validation_0-auc:0.999263	validation_0-logloss:0.008732
# [154]	validation_0-auc:0.999263	validation_0-logloss:0.008726
# [155]	validation_0-auc:0.999264	validation_0-logloss:0.008723
# [156]	validation_0-auc:0.999271	validation_0-logloss:0.008719
# [157]	validation_0-auc:0.999274	validation_0-logloss:0.00871
# [158]	validation_0-auc:0.999276	validation_0-logloss:0.008704
# [159]	validation_0-auc:0.999277	validation_0-logloss:0.008696
# [160]	validation_0-auc:0.999281	validation_0-logloss:0.008688
# [161]	validation_0-auc:0.999279	validation_0-logloss:0.008683
# [162]	validation_0-auc:0.999279	validation_0-logloss:0.008682
# [163]	validation_0-auc:0.999281	validation_0-logloss:0.008679
# [164]	validation_0-auc:0.999282	validation_0-logloss:0.008673
# [165]	validation_0-auc:0.999286	validation_0-logloss:0.008665
# [166]	validation_0-auc:0.999288	validation_0-logloss:0.008654
# [167]	validation_0-auc:0.999295	validation_0-logloss:0.008641
# [168]	validation_0-auc:0.9993	validation_0-logloss:0.008636
# [169]	validation_0-auc:0.9993	validation_0-logloss:0.008634
# [170]	validation_0-auc:0.999307	validation_0-logloss:0.008628
# [171]	validation_0-auc:0.999309	validation_0-logloss:0.008623
# [172]	validation_0-auc:0.99931	validation_0-logloss:0.008617
# [173]	validation_0-auc:0.999319	validation_0-logloss:0.00861
# [174]	validation_0-auc:0.999325	validation_0-logloss:0.008596
# [175]	validation_0-auc:0.999327	validation_0-logloss:0.008595
# [176]	validation_0-auc:0.999327	validation_0-logloss:0.008594
# [177]	validation_0-auc:0.999335	validation_0-logloss:0.008583
# [178]	validation_0-auc:0.999337	validation_0-logloss:0.008579
# [179]	validation_0-auc:0.999339	validation_0-logloss:0.008576
# [180]	validation_0-auc:0.99934	validation_0-logloss:0.008576
# [181]	validation_0-auc:0.99934	validation_0-logloss:0.008571
# [182]	validation_0-auc:0.999339	validation_0-logloss:0.008566
# [183]	validation_0-auc:0.999341	validation_0-logloss:0.008568
# [184]	validation_0-auc:0.999341	validation_0-logloss:0.008562
# [185]	validation_0-auc:0.999341	validation_0-logloss:0.008559
# [186]	validation_0-auc:0.999342	validation_0-logloss:0.008558
# [187]	validation_0-auc:0.999345	validation_0-logloss:0.00855
# [188]	validation_0-auc:0.999347	validation_0-logloss:0.008548
# [189]	validation_0-auc:0.999346	validation_0-logloss:0.008545
# [190]	validation_0-auc:0.999347	validation_0-logloss:0.008543
# [191]	validation_0-auc:0.999349	validation_0-logloss:0.008535
# [192]	validation_0-auc:0.99935	validation_0-logloss:0.008532
# [193]	validation_0-auc:0.99935	validation_0-logloss:0.008531
# [194]	validation_0-auc:0.999352	validation_0-logloss:0.008528
# [195]	validation_0-auc:0.999354	validation_0-logloss:0.008529
# [196]	validation_0-auc:0.999354	validation_0-logloss:0.008528
# [197]	validation_0-auc:0.999354	validation_0-logloss:0.008527
# [198]	validation_0-auc:0.999354	validation_0-logloss:0.008525
# [199]	validation_0-auc:0.999356	validation_0-logloss:0.008517
# [200]	validation_0-auc:0.999356	validation_0-logloss:0.008513
# [201]	validation_0-auc:0.999357	validation_0-logloss:0.008512
# [202]	validation_0-auc:0.999357	validation_0-logloss:0.008511
# [203]	validation_0-auc:0.99936	validation_0-logloss:0.008509
# [204]	validation_0-auc:0.99936	validation_0-logloss:0.008507
# [205]	validation_0-auc:0.99936	validation_0-logloss:0.008503
# [206]	validation_0-auc:0.999362	validation_0-logloss:0.008501
# [207]	validation_0-auc:0.999363	validation_0-logloss:0.008496
# [208]	validation_0-auc:0.999363	validation_0-logloss:0.008495
# [209]	validation_0-auc:0.999363	validation_0-logloss:0.008495
# [210]	validation_0-auc:0.999363	validation_0-logloss:0.008491
# [211]	validation_0-auc:0.999363	validation_0-logloss:0.008486
# [212]	validation_0-auc:0.999367	validation_0-logloss:0.008482
# [213]	validation_0-auc:0.999367	validation_0-logloss:0.008482
# [214]	validation_0-auc:0.999366	validation_0-logloss:0.008478
# [215]	validation_0-auc:0.999367	validation_0-logloss:0.008473
# [216]	validation_0-auc:0.999366	validation_0-logloss:0.008473
# [217]	validation_0-auc:0.999368	validation_0-logloss:0.008471
# [218]	validation_0-auc:0.999369	validation_0-logloss:0.008469
# [219]	validation_0-auc:0.999371	validation_0-logloss:0.008466
# [220]	validation_0-auc:0.999373	validation_0-logloss:0.008465
# [221]	validation_0-auc:0.999373	validation_0-logloss:0.00846
# [222]	validation_0-auc:0.999375	validation_0-logloss:0.008458
# [223]	validation_0-auc:0.999374	validation_0-logloss:0.008455
# [224]	validation_0-auc:0.999379	validation_0-logloss:0.008448
# [225]	validation_0-auc:0.99938	validation_0-logloss:0.008445
# [226]	validation_0-auc:0.999381	validation_0-logloss:0.008442
# [227]	validation_0-auc:0.999382	validation_0-logloss:0.008437
# [228]	validation_0-auc:0.999385	validation_0-logloss:0.008435
# [229]	validation_0-auc:0.999385	validation_0-logloss:0.008435
# [230]	validation_0-auc:0.999388	validation_0-logloss:0.008432
# [231]	validation_0-auc:0.999388	validation_0-logloss:0.00843
# [232]	validation_0-auc:0.999388	validation_0-logloss:0.00843
# [233]	validation_0-auc:0.99939	validation_0-logloss:0.008427
# [234]	validation_0-auc:0.99939	validation_0-logloss:0.008427
# [235]	validation_0-auc:0.99939	validation_0-logloss:0.008427
# [236]	validation_0-auc:0.999391	validation_0-logloss:0.008428
# [237]	validation_0-auc:0.999391	validation_0-logloss:0.008427
# [238]	validation_0-auc:0.999392	validation_0-logloss:0.008426
# [239]	validation_0-auc:0.999392	validation_0-logloss:0.008425
# [240]	validation_0-auc:0.999394	validation_0-logloss:0.008423
# [241]	validation_0-auc:0.999396	validation_0-logloss:0.00842
# [242]	validation_0-auc:0.999395	validation_0-logloss:0.008418
# [243]	validation_0-auc:0.999397	validation_0-logloss:0.008415
# [244]	validation_0-auc:0.999396	validation_0-logloss:0.008412
# [245]	validation_0-auc:0.999396	validation_0-logloss:0.008413
# [246]	validation_0-auc:0.999396	validation_0-logloss:0.008411
# [247]	validation_0-auc:0.999396	validation_0-logloss:0.00841
# [248]	validation_0-auc:0.999396	validation_0-logloss:0.00841
# [249]	validation_0-auc:0.999396	validation_0-logloss:0.008406
# [250]	validation_0-auc:0.999396	validation_0-logloss:0.008404
# [251]	validation_0-auc:0.999396	validation_0-logloss:0.008403
# [252]	validation_0-auc:0.999397	validation_0-logloss:0.008398
# [253]	validation_0-auc:0.999397	validation_0-logloss:0.008398
# [254]	validation_0-auc:0.999397	validation_0-logloss:0.008397
# [255]	validation_0-auc:0.999398	validation_0-logloss:0.008397
# [256]	validation_0-auc:0.999397	validation_0-logloss:0.008395
# [257]	validation_0-auc:0.999398	validation_0-logloss:0.008394
# [258]	validation_0-auc:0.999397	validation_0-logloss:0.008392
# [259]	validation_0-auc:0.999399	validation_0-logloss:0.00839
# [260]	validation_0-auc:0.999399	validation_0-logloss:0.008387
# [261]	validation_0-auc:0.9994	validation_0-logloss:0.008384
# [262]	validation_0-auc:0.999401	validation_0-logloss:0.008383
# [263]	validation_0-auc:0.999401	validation_0-logloss:0.008384
# [264]	validation_0-auc:0.999401	validation_0-logloss:0.00838
# [265]	validation_0-auc:0.999401	validation_0-logloss:0.008378
# [266]	validation_0-auc:0.9994	validation_0-logloss:0.008377
# [267]	validation_0-auc:0.999401	validation_0-logloss:0.008375
# [268]	validation_0-auc:0.999401	validation_0-logloss:0.008374
# [269]	validation_0-auc:0.999402	validation_0-logloss:0.008373
# [270]	validation_0-auc:0.999402	validation_0-logloss:0.008372
# [271]	validation_0-auc:0.999402	validation_0-logloss:0.008372
# [272]	validation_0-auc:0.999403	validation_0-logloss:0.008368
# [273]	validation_0-auc:0.999406	validation_0-logloss:0.008366
# [274]	validation_0-auc:0.999407	validation_0-logloss:0.008366
# [275]	validation_0-auc:0.999406	validation_0-logloss:0.008365
# [276]	validation_0-auc:0.999406	validation_0-logloss:0.00836
# [277]	validation_0-auc:0.999407	validation_0-logloss:0.008358
# [278]	validation_0-auc:0.999408	validation_0-logloss:0.008358
# [279]	validation_0-auc:0.999408	validation_0-logloss:0.008357
# [280]	validation_0-auc:0.999407	validation_0-logloss:0.008356
# [281]	validation_0-auc:0.999411	validation_0-logloss:0.008353
# [282]	validation_0-auc:0.999411	validation_0-logloss:0.008353
# [283]	validation_0-auc:0.999411	validation_0-logloss:0.008353
# [284]	validation_0-auc:0.999414	validation_0-logloss:0.008351
# [285]	validation_0-auc:0.999414	validation_0-logloss:0.00835
# [286]	validation_0-auc:0.999414	validation_0-logloss:0.00835
# [287]	validation_0-auc:0.999414	validation_0-logloss:0.008349
# [288]	validation_0-auc:0.999413	validation_0-logloss:0.008347
# [289]	validation_0-auc:0.999414	validation_0-logloss:0.008347
# [290]	validation_0-auc:0.999414	validation_0-logloss:0.008347
# [291]	validation_0-auc:0.999414	validation_0-logloss:0.008346
# [292]	validation_0-auc:0.999413	validation_0-logloss:0.008344
# [293]	validation_0-auc:0.999413	validation_0-logloss:0.008343
# [294]	validation_0-auc:0.999413	validation_0-logloss:0.00834
# [295]	validation_0-auc:0.999413	validation_0-logloss:0.00834
# [296]	validation_0-auc:0.999415	validation_0-logloss:0.008338
# [297]	validation_0-auc:0.999415	validation_0-logloss:0.008337
# [298]	validation_0-auc:0.999415	validation_0-logloss:0.008336
# [299]	validation_0-auc:0.999416	validation_0-logloss:0.008333
# [300]	validation_0-auc:0.999416	validation_0-logloss:0.00833
# [301]	validation_0-auc:0.999417	validation_0-logloss:0.008329
# [302]	validation_0-auc:0.999417	validation_0-logloss:0.008327
# [303]	validation_0-auc:0.999417	validation_0-logloss:0.008325
# [304]	validation_0-auc:0.999417	validation_0-logloss:0.008322
# [305]	validation_0-auc:0.999417	validation_0-logloss:0.008322
# [306]	validation_0-auc:0.999417	validation_0-logloss:0.008323
# [307]	validation_0-auc:0.999417	validation_0-logloss:0.00832
# [308]	validation_0-auc:0.999418	validation_0-logloss:0.008319
# [309]	validation_0-auc:0.999417	validation_0-logloss:0.008317
# [310]	validation_0-auc:0.999417	validation_0-logloss:0.008316
# [311]	validation_0-auc:0.99942	validation_0-logloss:0.008314
# [312]	validation_0-auc:0.99942	validation_0-logloss:0.008313
# [313]	validation_0-auc:0.99942	validation_0-logloss:0.008313
# [314]	validation_0-auc:0.99942	validation_0-logloss:0.008312
# [315]	validation_0-auc:0.99942	validation_0-logloss:0.008312
# [316]	validation_0-auc:0.99942	validation_0-logloss:0.008312
# [317]	validation_0-auc:0.99942	validation_0-logloss:0.008311
# [318]	validation_0-auc:0.99942	validation_0-logloss:0.008311
# [319]	validation_0-auc:0.99942	validation_0-logloss:0.008311
# [320]	validation_0-auc:0.99942	validation_0-logloss:0.00831
# [321]	validation_0-auc:0.999423	validation_0-logloss:0.008308
# [322]	validation_0-auc:0.999423	validation_0-logloss:0.008306
# [323]	validation_0-auc:0.999422	validation_0-logloss:0.008306
# [324]	validation_0-auc:0.999423	validation_0-logloss:0.008306
# [325]	validation_0-auc:0.999423	validation_0-logloss:0.008306
# [326]	validation_0-auc:0.999424	validation_0-logloss:0.008304
# [327]	validation_0-auc:0.999424	validation_0-logloss:0.008304
# [328]	validation_0-auc:0.999424	validation_0-logloss:0.008304
# [329]	validation_0-auc:0.999424	validation_0-logloss:0.008305
# [330]	validation_0-auc:0.999424	validation_0-logloss:0.008304
# [331]	validation_0-auc:0.999423	validation_0-logloss:0.008304
# [332]	validation_0-auc:0.999424	validation_0-logloss:0.008304
# [333]	validation_0-auc:0.999424	validation_0-logloss:0.008304
# [334]	validation_0-auc:0.999425	validation_0-logloss:0.008303
# [335]	validation_0-auc:0.999425	validation_0-logloss:0.008302
# [336]	validation_0-auc:0.999426	validation_0-logloss:0.0083
# [337]	validation_0-auc:0.999428	validation_0-logloss:0.008299
# [338]	validation_0-auc:0.999428	validation_0-logloss:0.008296
# [339]	validation_0-auc:0.999428	validation_0-logloss:0.008293
# [340]	validation_0-auc:0.999428	validation_0-logloss:0.00829
# [341]	validation_0-auc:0.999428	validation_0-logloss:0.00829
# [342]	validation_0-auc:0.999428	validation_0-logloss:0.008289
# [343]	validation_0-auc:0.999429	validation_0-logloss:0.008287
# [344]	validation_0-auc:0.99943	validation_0-logloss:0.008285
# [345]	validation_0-auc:0.999431	validation_0-logloss:0.008285
# [346]	validation_0-auc:0.99943	validation_0-logloss:0.008284
# [347]	validation_0-auc:0.999431	validation_0-logloss:0.008284
# [348]	validation_0-auc:0.999431	validation_0-logloss:0.008282
# [349]	validation_0-auc:0.999433	validation_0-logloss:0.008277
# [350]	validation_0-auc:0.999433	validation_0-logloss:0.008277
# [351]	validation_0-auc:0.999435	validation_0-logloss:0.008275
# [352]	validation_0-auc:0.999435	validation_0-logloss:0.008273
# [353]	validation_0-auc:0.999435	validation_0-logloss:0.008271
# [354]	validation_0-auc:0.999435	validation_0-logloss:0.008271
# [355]	validation_0-auc:0.999435	validation_0-logloss:0.00827
# [356]	validation_0-auc:0.999434	validation_0-logloss:0.00827
# [357]	validation_0-auc:0.999435	validation_0-logloss:0.008271
# [358]	validation_0-auc:0.999434	validation_0-logloss:0.00827
# [359]	validation_0-auc:0.999435	validation_0-logloss:0.008269
# [360]	validation_0-auc:0.999435	validation_0-logloss:0.008269
# [361]	validation_0-auc:0.999435	validation_0-logloss:0.008269
# [362]	validation_0-auc:0.999434	validation_0-logloss:0.008267
# [363]	validation_0-auc:0.999434	validation_0-logloss:0.008267
# [364]	validation_0-auc:0.999434	validation_0-logloss:0.008267
# [365]	validation_0-auc:0.999435	validation_0-logloss:0.008266
# [366]	validation_0-auc:0.999435	validation_0-logloss:0.008266
# [367]	validation_0-auc:0.999435	validation_0-logloss:0.008265
# [368]	validation_0-auc:0.999435	validation_0-logloss:0.008265
# [369]	validation_0-auc:0.999437	validation_0-logloss:0.008263
# [370]	validation_0-auc:0.999438	validation_0-logloss:0.008263
# [371]	validation_0-auc:0.999438	validation_0-logloss:0.00826
# [372]	validation_0-auc:0.999438	validation_0-logloss:0.00826
# [373]	validation_0-auc:0.999438	validation_0-logloss:0.008259
# [374]	validation_0-auc:0.999438	validation_0-logloss:0.008258
# [375]	validation_0-auc:0.999438	validation_0-logloss:0.008257
# [376]	validation_0-auc:0.999439	validation_0-logloss:0.008256
# [377]	validation_0-auc:0.999439	validation_0-logloss:0.008256
# [378]	validation_0-auc:0.999439	validation_0-logloss:0.008255
# [379]	validation_0-auc:0.999439	validation_0-logloss:0.008254
# [380]	validation_0-auc:0.99944	validation_0-logloss:0.008253
# [381]	validation_0-auc:0.99944	validation_0-logloss:0.008252
# [382]	validation_0-auc:0.999441	validation_0-logloss:0.008251
# [383]	validation_0-auc:0.999441	validation_0-logloss:0.008248
# [384]	validation_0-auc:0.999441	validation_0-logloss:0.008249
# [385]	validation_0-auc:0.999441	validation_0-logloss:0.008248
# [386]	validation_0-auc:0.999441	validation_0-logloss:0.008248
# [387]	validation_0-auc:0.999441	validation_0-logloss:0.008248
# [388]	validation_0-auc:0.999442	validation_0-logloss:0.008248
# [389]	validation_0-auc:0.999442	validation_0-logloss:0.008248
# [390]	validation_0-auc:0.999442	validation_0-logloss:0.008247
# [391]	validation_0-auc:0.999442	validation_0-logloss:0.008247
# [392]	validation_0-auc:0.999442	validation_0-logloss:0.008246
# [393]	validation_0-auc:0.999442	validation_0-logloss:0.008245
# [394]	validation_0-auc:0.999442	validation_0-logloss:0.008246
# [395]	validation_0-auc:0.999442	validation_0-logloss:0.008245
# [396]	validation_0-auc:0.999443	validation_0-logloss:0.008242
# [397]	validation_0-auc:0.999443	validation_0-logloss:0.008243
# [398]	validation_0-auc:0.999443	validation_0-logloss:0.008242
# [399]	validation_0-auc:0.999443	validation_0-logloss:0.008241
# [400]	validation_0-auc:0.999443	validation_0-logloss:0.00824
# [401]	validation_0-auc:0.999444	validation_0-logloss:0.008239
# [402]	validation_0-auc:0.999443	validation_0-logloss:0.008238
# [403]	validation_0-auc:0.999444	validation_0-logloss:0.008237
# [404]	validation_0-auc:0.999444	validation_0-logloss:0.008237
# [405]	validation_0-auc:0.999445	validation_0-logloss:0.008235
# [406]	validation_0-auc:0.999446	validation_0-logloss:0.008236
# [407]	validation_0-auc:0.999445	validation_0-logloss:0.008236
# [408]	validation_0-auc:0.999445	validation_0-logloss:0.008235
# [409]	validation_0-auc:0.999446	validation_0-logloss:0.008234
# [410]	validation_0-auc:0.999446	validation_0-logloss:0.008234
# [411]	validation_0-auc:0.999446	validation_0-logloss:0.008234
# [412]	validation_0-auc:0.999446	validation_0-logloss:0.008234
# [413]	validation_0-auc:0.999446	validation_0-logloss:0.008233
# [414]	validation_0-auc:0.999445	validation_0-logloss:0.008233
# [415]	validation_0-auc:0.999445	validation_0-logloss:0.008232
# [416]	validation_0-auc:0.999445	validation_0-logloss:0.008232
# [417]	validation_0-auc:0.999445	validation_0-logloss:0.008232
# [418]	validation_0-auc:0.999445	validation_0-logloss:0.008232
# [419]	validation_0-auc:0.999445	validation_0-logloss:0.008232
# [420]	validation_0-auc:0.999445	validation_0-logloss:0.008231
# [421]	validation_0-auc:0.999446	validation_0-logloss:0.008231
# [422]	validation_0-auc:0.999446	validation_0-logloss:0.008232
# [423]	validation_0-auc:0.999446	validation_0-logloss:0.008231
# [424]	validation_0-auc:0.999447	validation_0-logloss:0.008232
# [425]	validation_0-auc:0.999448	validation_0-logloss:0.008231
# [426]	validation_0-auc:0.999448	validation_0-logloss:0.008231
# [427]	validation_0-auc:0.999451	validation_0-logloss:0.008228
# [428]	validation_0-auc:0.999451	validation_0-logloss:0.008228
# [429]	validation_0-auc:0.999451	validation_0-logloss:0.008226
# [430]	validation_0-auc:0.999451	validation_0-logloss:0.008226
# [431]	validation_0-auc:0.999451	validation_0-logloss:0.008225
# [432]	validation_0-auc:0.999452	validation_0-logloss:0.008224
# [433]	validation_0-auc:0.999452	validation_0-logloss:0.008224
# [434]	validation_0-auc:0.999454	validation_0-logloss:0.008221
# [435]	validation_0-auc:0.999454	validation_0-logloss:0.008218
# [436]	validation_0-auc:0.999454	validation_0-logloss:0.008218
# [437]	validation_0-auc:0.999454	validation_0-logloss:0.008217
# [438]	validation_0-auc:0.999454	validation_0-logloss:0.008216
# [439]	validation_0-auc:0.999454	validation_0-logloss:0.008214
# [440]	validation_0-auc:0.999454	validation_0-logloss:0.008213
# [441]	validation_0-auc:0.999455	validation_0-logloss:0.008213
# [442]	validation_0-auc:0.999455	validation_0-logloss:0.008212
# [443]	validation_0-auc:0.999455	validation_0-logloss:0.008211
# [444]	validation_0-auc:0.999454	validation_0-logloss:0.008209
# [445]	validation_0-auc:0.999454	validation_0-logloss:0.008209
# [446]	validation_0-auc:0.999455	validation_0-logloss:0.008207
# [447]	validation_0-auc:0.999455	validation_0-logloss:0.008206
# [448]	validation_0-auc:0.999455	validation_0-logloss:0.008206
# [449]	validation_0-auc:0.999455	validation_0-logloss:0.008205
# [450]	validation_0-auc:0.999455	validation_0-logloss:0.008205
# [451]	validation_0-auc:0.999455	validation_0-logloss:0.008205
# [452]	validation_0-auc:0.999454	validation_0-logloss:0.008204
# [453]	validation_0-auc:0.999454	validation_0-logloss:0.008203
# [454]	validation_0-auc:0.999454	validation_0-logloss:0.008203
# [455]	validation_0-auc:0.999455	validation_0-logloss:0.008202
# [456]	validation_0-auc:0.999455	validation_0-logloss:0.008202
# [457]	validation_0-auc:0.999455	validation_0-logloss:0.008202
# [458]	validation_0-auc:0.999454	validation_0-logloss:0.008202
# [459]	validation_0-auc:0.999453	validation_0-logloss:0.008202
# [460]	validation_0-auc:0.999453	validation_0-logloss:0.008202
# [461]	validation_0-auc:0.999453	validation_0-logloss:0.008202
# [462]	validation_0-auc:0.999454	validation_0-logloss:0.008201
# [463]	validation_0-auc:0.999454	validation_0-logloss:0.008201
# [464]	validation_0-auc:0.999454	validation_0-logloss:0.008201
# [465]	validation_0-auc:0.999454	validation_0-logloss:0.0082
# [466]	validation_0-auc:0.999454	validation_0-logloss:0.008201
# [467]	validation_0-auc:0.999454	validation_0-logloss:0.0082
# [468]	validation_0-auc:0.999455	validation_0-logloss:0.0082
# [469]	validation_0-auc:0.999455	validation_0-logloss:0.0082
# [470]	validation_0-auc:0.999455	validation_0-logloss:0.008198
# [471]	validation_0-auc:0.999455	validation_0-logloss:0.008198
# [472]	validation_0-auc:0.999456	validation_0-logloss:0.008197
# [473]	validation_0-auc:0.999456	validation_0-logloss:0.008197
# [474]	validation_0-auc:0.999456	validation_0-logloss:0.008197
# [475]	validation_0-auc:0.999456	validation_0-logloss:0.008196
# [476]	validation_0-auc:0.999456	validation_0-logloss:0.008197
# [477]	validation_0-auc:0.999456	validation_0-logloss:0.008197
# [478]	validation_0-auc:0.999457	validation_0-logloss:0.008196
# [479]	validation_0-auc:0.999457	validation_0-logloss:0.008196
# [480]	validation_0-auc:0.999457	validation_0-logloss:0.008195
# [481]	validation_0-auc:0.999457	validation_0-logloss:0.008195
# [482]	validation_0-auc:0.999457	validation_0-logloss:0.008195
# [483]	validation_0-auc:0.999457	validation_0-logloss:0.008194
# [484]	validation_0-auc:0.999458	validation_0-logloss:0.008193
# [485]	validation_0-auc:0.999458	validation_0-logloss:0.008193
# [486]	validation_0-auc:0.999458	validation_0-logloss:0.008192
# [487]	validation_0-auc:0.999458	validation_0-logloss:0.008192
# [488]	validation_0-auc:0.999458	validation_0-logloss:0.00819
# [489]	validation_0-auc:0.999458	validation_0-logloss:0.008191
# [490]	validation_0-auc:0.999458	validation_0-logloss:0.00819
# [491]	validation_0-auc:0.999459	validation_0-logloss:0.008189
# [492]	validation_0-auc:0.999459	validation_0-logloss:0.008189
# [493]	validation_0-auc:0.999458	validation_0-logloss:0.008188
# [494]	validation_0-auc:0.999458	validation_0-logloss:0.008188
# [495]	validation_0-auc:0.999458	validation_0-logloss:0.008187
# [496]	validation_0-auc:0.999458	validation_0-logloss:0.008188
# [497]	validation_0-auc:0.999458	validation_0-logloss:0.008188
# [498]	validation_0-auc:0.999458	validation_0-logloss:0.008187
# [499]	validation_0-auc:0.999462	validation_0-logloss:0.008183
# [500]	validation_0-auc:0.999462	validation_0-logloss:0.008183
# [501]	validation_0-auc:0.999462	validation_0-logloss:0.008183
# [502]	validation_0-auc:0.999462	validation_0-logloss:0.008182
# [503]	validation_0-auc:0.999462	validation_0-logloss:0.008181
# [504]	validation_0-auc:0.999462	validation_0-logloss:0.00818
# [505]	validation_0-auc:0.999462	validation_0-logloss:0.008179
# [506]	validation_0-auc:0.999462	validation_0-logloss:0.008179
# [507]	validation_0-auc:0.999462	validation_0-logloss:0.008178
# [508]	validation_0-auc:0.999462	validation_0-logloss:0.008178
# [509]	validation_0-auc:0.999462	validation_0-logloss:0.008177
# [510]	validation_0-auc:0.999462	validation_0-logloss:0.008177
# [511]	validation_0-auc:0.999462	validation_0-logloss:0.008177
# [512]	validation_0-auc:0.999462	validation_0-logloss:0.008178
# [513]	validation_0-auc:0.999462	validation_0-logloss:0.008178
# [514]	validation_0-auc:0.999462	validation_0-logloss:0.008179
# [515]	validation_0-auc:0.999462	validation_0-logloss:0.008179
# [516]	validation_0-auc:0.999462	validation_0-logloss:0.008178
# [517]	validation_0-auc:0.999462	validation_0-logloss:0.008177
# [518]	validation_0-auc:0.999462	validation_0-logloss:0.008175
# [519]	validation_0-auc:0.999462	validation_0-logloss:0.008175
# [520]	validation_0-auc:0.999462	validation_0-logloss:0.008175
# [521]	validation_0-auc:0.999462	validation_0-logloss:0.008175
# [522]	validation_0-auc:0.999462	validation_0-logloss:0.008174
# [523]	validation_0-auc:0.999462	validation_0-logloss:0.008173
# [524]	validation_0-auc:0.999462	validation_0-logloss:0.008173
# [525]	validation_0-auc:0.999462	validation_0-logloss:0.008174
# [526]	validation_0-auc:0.999462	validation_0-logloss:0.008174
# [527]	validation_0-auc:0.999463	validation_0-logloss:0.008174
# [528]	validation_0-auc:0.999463	validation_0-logloss:0.008174
# [529]	validation_0-auc:0.999463	validation_0-logloss:0.008172
# [530]	validation_0-auc:0.999463	validation_0-logloss:0.008173
# [531]	validation_0-auc:0.999462	validation_0-logloss:0.008174
# [532]	validation_0-auc:0.999462	validation_0-logloss:0.008174
# [533]	validation_0-auc:0.999463	validation_0-logloss:0.008173
# [534]	validation_0-auc:0.999463	validation_0-logloss:0.008172
# [535]	validation_0-auc:0.999463	validation_0-logloss:0.008172
# [536]	validation_0-auc:0.999463	validation_0-logloss:0.008172
# [537]	validation_0-auc:0.999463	validation_0-logloss:0.008172
# [538]	validation_0-auc:0.999463	validation_0-logloss:0.008172
# [539]	validation_0-auc:0.999463	validation_0-logloss:0.00817
# [540]	validation_0-auc:0.999468	validation_0-logloss:0.008166
# [541]	validation_0-auc:0.99947	validation_0-logloss:0.008164
# [542]	validation_0-auc:0.99947	validation_0-logloss:0.008164
# [543]	validation_0-auc:0.99947	validation_0-logloss:0.008164
# [544]	validation_0-auc:0.999471	validation_0-logloss:0.008161
# [545]	validation_0-auc:0.999471	validation_0-logloss:0.008161
# [546]	validation_0-auc:0.999472	validation_0-logloss:0.00816
# [547]	validation_0-auc:0.999472	validation_0-logloss:0.00816
# [548]	validation_0-auc:0.999472	validation_0-logloss:0.00816
# [549]	validation_0-auc:0.999472	validation_0-logloss:0.008159
# [550]	validation_0-auc:0.999472	validation_0-logloss:0.008159
# [551]	validation_0-auc:0.999475	validation_0-logloss:0.008156
# [552]	validation_0-auc:0.999476	validation_0-logloss:0.008155
# [553]	validation_0-auc:0.999476	validation_0-logloss:0.008154
# [554]	validation_0-auc:0.999476	validation_0-logloss:0.008153
# [555]	validation_0-auc:0.999476	validation_0-logloss:0.008154
# [556]	validation_0-auc:0.999476	validation_0-logloss:0.008154
# [557]	validation_0-auc:0.999476	validation_0-logloss:0.008154
# [558]	validation_0-auc:0.999476	validation_0-logloss:0.008154
# [559]	validation_0-auc:0.999476	validation_0-logloss:0.008153
# [560]	validation_0-auc:0.999476	validation_0-logloss:0.008154
# [561]	validation_0-auc:0.999477	validation_0-logloss:0.008152
# [562]	validation_0-auc:0.999477	validation_0-logloss:0.008152
# [563]	validation_0-auc:0.999477	validation_0-logloss:0.008153
# [564]	validation_0-auc:0.999478	validation_0-logloss:0.008152
# [565]	validation_0-auc:0.999478	validation_0-logloss:0.008153
# [566]	validation_0-auc:0.999478	validation_0-logloss:0.008153
# [567]	validation_0-auc:0.999478	validation_0-logloss:0.008154
# [568]	validation_0-auc:0.999478	validation_0-logloss:0.008154
# [569]	validation_0-auc:0.999478	validation_0-logloss:0.008154
# [570]	validation_0-auc:0.999478	validation_0-logloss:0.008154
# [571]	validation_0-auc:0.999478	validation_0-logloss:0.008154
# [572]	validation_0-auc:0.999478	validation_0-logloss:0.008154
# [573]	validation_0-auc:0.999478	validation_0-logloss:0.008154
# [574]	validation_0-auc:0.999478	validation_0-logloss:0.008153
# [575]	validation_0-auc:0.999478	validation_0-logloss:0.008153
# [576]	validation_0-auc:0.999478	validation_0-logloss:0.008153
# [577]	validation_0-auc:0.999478	validation_0-logloss:0.008153
# [578]	validation_0-auc:0.999478	validation_0-logloss:0.008153
# [579]	validation_0-auc:0.999479	validation_0-logloss:0.008153
# [580]	validation_0-auc:0.999479	validation_0-logloss:0.008154
# [581]	validation_0-auc:0.999479	validation_0-logloss:0.008154
# Stopping. Best iteration:
# [561]	validation_0-auc:0.999477	validation_0-logloss:0.008152
#
# 0:05:34.292603

# %%
predicted_y = xgbmodel.predict(x_val.values)
accuracy_score(y_val.values, predicted_y)
# Out:
# 0.9979110392269605

# %% [markdown]
# ### XGBoost Feature Importance

# %%
mean_dict = {}
counter = 0
fi_array = xgbmodel.get_booster().get_score(importance_type = 'gain')

for col in df_process_X.columns:
  mean_dict[col] = fi_array['f'+str(counter)]
  counter += 1

fi_dict = {}
fi_dict['mean'] = mean_dict
fi_df = pd.DataFrame(fi_dict, index=df_process_X.columns)
fi_df['perc'] = fi_df['mean']/fi_df['mean'].sum()

# %%
fi_df
# Out:
#                  mean      perc
# app         60.309516  0.001262
# device      37.497279  0.000785
# os           4.640709  0.000097
# channel     25.214387  0.000528
# hour      2182.430285  0.045665
# day      45482.147025  0.951664

# %% [markdown]
# ## Reducing Dataset back to original balance

# %% [markdown]
# Out of curiosity, we reduced the positive samples in our training data back to the percentage in the original dataset. Originally, there were only 0.24% positive observations. We describe the motivation for doing this in our report.

# %%
exp = pd.read_csv('combined.csv')
# do the same data preprocessing 
exp.drop(['Unnamed: 0', 'attributed_time'], axis = 1, inplace=True)
exp['day'] = exp['click_time'].apply(find_day)
exp['hour'] = exp['click_time'].apply(find_hour)
exp.drop('click_time', inplace = True, axis = 1)
exp.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#        ip  app  device  os  channel  is_attributed  day  hour
# 0  204158   35       1  13       21              1    0    15
# 1   29692    9       1  22      215              1    0    16
# 2   64516   35       1  13       21              1    0    16
# 3  172429   35       1  46      274              1    0    16
# 4  199085   35       1  13      274              1    0    16

# %%
# number of positives we want
num_pos = round(len(exp[exp['is_attributed'] == 0]) /0.9966 * 0.0024)
pos = exp[exp['is_attributed'] == 1].sample(num_pos)
pos.head()
# Out:
#             ip  app  device  os  channel  is_attributed  day  hour
# 10071   186150   18       1  19      134              1    0    21
# 214375  108877   19       0   0      213              1    2     4
# 405019   27782    9       1  14      334              1    3     9
# 116142    5524   35       1  10      274              1    1    11
# 366912  109938   35       1  19       21              1    3     5

# %%
# put it back together with all the neg samples
original = pd.concat([pos, exp[exp['is_attributed'] == 0]])
original.reset_index(drop=True, inplace=True)
original.head()
# Out:
#        ip  app  device  os  channel  is_attributed  day  hour
# 0  186150   18       1  19      134              1    0    21
# 1  108877   19       0   0      213              1    2     4
# 2   27782    9       1  14      334              1    3     9
# 3    5524   35       1  10      274              1    1    11
# 4  109938   35       1  19       21              1    3     5

# %%
# create the lgb dataset
o_labels = original['is_attributed']
original.drop('is_attributed', inplace = True, axis = 1)
o_data = lgb.Dataset(original, label = o_labels, categorical_feature=list(original.columns),free_raw_data=False)

# %%
#run the model
o_start = datetime.datetime.now()
o_eval = lgb.cv(params=params, train_set = o_data,nfold=5, verbose_eval = 10, early_stopping_rounds = 100, return_cvbooster=True)
o_time_taken = datetime.datetime.now() - o_start
print(o_time_taken)
# Out:
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:577: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/basic.py:2065: UserWarning: Using categorical_feature in Dataset.
#   _log_warning('Using categorical_feature in Dataset.')
# [LightGBM] [Info] Number of positive: 1942, number of negative: 806629
# [LightGBM] [Info] [cross_entropy:Init]: (metric) labels passed interval [0, 1] check
# [LightGBM] [Info] [cross_entropy:Init]: sum-of-weights = 808571.000000
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.071104 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 17870
# [LightGBM] [Info] Number of data points in the train set: 808571, number of used features: 7
# [LightGBM] [Info] [cross_entropy:Init]: (metric) labels passed interval [0, 1] check
# [LightGBM] [Info] [cross_entropy:Init]: sum-of-weights = 202143.000000
# [LightGBM] [Info] Number of positive: 1942, number of negative: 806629
# [LightGBM] [Info] [cross_entropy:Init]: (metric) labels passed interval [0, 1] check
# [LightGBM] [Info] [cross_entropy:Init]: sum-of-weights = 808571.000000
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.071226 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 17870
# [LightGBM] [Info] Number of data points in the train set: 808571, number of used features: 7
# [LightGBM] [Info] [cross_entropy:Init]: (metric) labels passed interval [0, 1] check
# [LightGBM] [Info] [cross_entropy:Init]: sum-of-weights = 202143.000000
# [LightGBM] [Info] Number of positive: 1942, number of negative: 806629
# [LightGBM] [Info] [cross_entropy:Init]: (metric) labels passed interval [0, 1] check
# [LightGBM] [Info] [cross_entropy:Init]: sum-of-weights = 808571.000000
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.072323 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 17870
# [LightGBM] [Info] Number of data points in the train set: 808571, number of used features: 7
# [LightGBM] [Info] [cross_entropy:Init]: (metric) labels passed interval [0, 1] check
# [LightGBM] [Info] [cross_entropy:Init]: sum-of-weights = 202143.000000
# [LightGBM] [Info] Number of positive: 1943, number of negative: 806628
# [LightGBM] [Info] [cross_entropy:Init]: (metric) labels passed interval [0, 1] check
# [LightGBM] [Info] [cross_entropy:Init]: sum-of-weights = 808571.000000
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.064007 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 17870
# [LightGBM] [Info] Number of data points in the train set: 808571, number of used features: 7
# [LightGBM] [Info] [cross_entropy:Init]: (metric) labels passed interval [0, 1] check
# [LightGBM] [Info] [cross_entropy:Init]: sum-of-weights = 202143.000000
# [LightGBM] [Info] Number of positive: 1943, number of negative: 806629
# [LightGBM] [Info] [cross_entropy:Init]: (metric) labels passed interval [0, 1] check
# [LightGBM] [Info] [cross_entropy:Init]: sum-of-weights = 808572.000000
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.075690 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 17870
# [LightGBM] [Info] Number of data points in the train set: 808572, number of used features: 7
# [LightGBM] [Info] [cross_entropy:Init]: (metric) labels passed interval [0, 1] check
# [LightGBM] [Info] [cross_entropy:Init]: sum-of-weights = 202142.000000
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.002402 -> initscore=-6.029145
# [LightGBM] [Info] Start training from score -6.029145
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:620: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.002402 -> initscore=-6.029145
# [LightGBM] [Info] Start training from score -6.029145
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.002402 -> initscore=-6.029145
# [LightGBM] [Info] Start training from score -6.029145
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.002403 -> initscore=-6.028629
# [LightGBM] [Info] Start training from score -6.028629
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.002403 -> initscore=-6.028631
# [LightGBM] [Info] Start training from score -6.028631
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [10]	cv_agg's auc: 0.993371 + 0.0108773	cv_agg's cross_entropy: 0.049495 + 0.0807091	cv_agg's l2: 0.00250057 + 0.00340373
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [20]	cv_agg's auc: 0.993232 + 0.00971855	cv_agg's cross_entropy: 0.0510266 + 0.092686	cv_agg's l2: 0.00286271 + 0.00464846
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [30]	cv_agg's auc: 0.993367 + 0.00939004	cv_agg's cross_entropy: 0.036748 + 0.0697115	cv_agg's l2: 0.00225226 + 0.00394181
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [40]	cv_agg's auc: 0.993335 + 0.00935829	cv_agg's cross_entropy: 0.0330238 + 0.0631704	cv_agg's l2: 0.00194584 + 0.0033578
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [50]	cv_agg's auc: 0.993594 + 0.00945121	cv_agg's cross_entropy: 0.0390715 + 0.0757978	cv_agg's l2: 0.00241155 + 0.00432613
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [60]	cv_agg's auc: 0.993543 + 0.00946427	cv_agg's cross_entropy: 0.037935 + 0.0736196	cv_agg's l2: 0.00251529 + 0.00450594
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [70]	cv_agg's auc: 0.993557 + 0.00946544	cv_agg's cross_entropy: 0.0374275 + 0.0727147	cv_agg's l2: 0.00220028 + 0.0038932
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [80]	cv_agg's auc: 0.993549 + 0.00942083	cv_agg's cross_entropy: 0.0397574 + 0.0774955	cv_agg's l2: 0.00262096 + 0.00477418
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [90]	cv_agg's auc: 0.993623 + 0.00937445	cv_agg's cross_entropy: 0.0442287 + 0.0863566	cv_agg's l2: 0.00322189 + 0.00591828
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [100]	cv_agg's auc: 0.99403 + 0.00855822	cv_agg's cross_entropy: 0.0393498 + 0.0766714	cv_agg's l2: 0.00226227 + 0.0040197
# 0:00:57.920643

# %%
o_means = getfeatureimpt(o_eval)
o_means
# Out:
#                  mean      perc
# day      9.001914e+07  0.772663
# hour     1.685945e+07  0.144710
# app      3.553834e+06  0.030504
# channel  2.909602e+06  0.024974
# os       2.421528e+06  0.020785
# device   4.474696e+05  0.003841
# ip       2.940206e+05  0.002524

# %% [markdown]
# #  Dataset 2: Credit Card Fraud Data

# %% [markdown]
# ## LightGBM on Credit Card Data

# %% [markdown]
# ### Download Data

# %%
# original dataset https://www.kaggle.com/mlg-ulb/creditcardfraud 
# !gdown --id 1tWqDuPaoKRiBiPJTi-jG5uP17AVrgzyc
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1tWqDuPaoKRiBiPJTi-jG5uP17AVrgzyc
# To: /content/creditcard.csv
# 100% 151M/151M [00:01<00:00, 117MB/s]

# %%
cc = pd.read_csv('/content/creditcard.csv')
cc.head()
# Out:
#    Time        V1        V2        V3  ...       V27       V28  Amount  Class
# 0   0.0 -1.359807 -0.072781  2.536347  ...  0.133558 -0.021053  149.62      0
# 1   0.0  1.191857  0.266151  0.166480  ... -0.008983  0.014724    2.69      0
# 2   1.0 -1.358354 -1.340163  1.773209  ... -0.055353 -0.059752  378.66      0
# 3   1.0 -0.966272 -0.185226  1.792993  ...  0.062723  0.061458  123.50      0
# 4   2.0 -1.158233  0.877737  1.548718  ...  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %% [markdown]
# The data has already treaed with PCA, and so there is not much preprocessing that can be done to pretreat the data since all the features are now Principal Components

# %% [markdown]
# ### Formatting the Data to work with LightGBM

# %%
cc_labels = cc['Class']
cc.drop('Class', axis = 1, inplace = True)
cc.head()
# Out:
#    Time        V1        V2        V3  ...       V26       V27       V28  Amount
# 0   0.0 -1.359807 -0.072781  2.536347  ... -0.189115  0.133558 -0.021053  149.62
# 1   0.0  1.191857  0.266151  0.166480  ...  0.125895 -0.008983  0.014724    2.69
# 2   1.0 -1.358354 -1.340163  1.773209  ... -0.139097 -0.055353 -0.059752  378.66
# 3   1.0 -0.966272 -0.185226  1.792993  ... -0.221929  0.062723  0.061458  123.50
# 4   2.0 -1.158233  0.877737  1.548718  ...  0.502292  0.219422  0.215153   69.99
#
# [5 rows x 30 columns]

# %%
cc_data = lgb.Dataset(cc, label = cc_labels,free_raw_data=False)

# %% [markdown]
# ### LightGBM on Credit Card Fraud Dataset

# %%
cc_start = datetime.datetime.now()
cc_eval = lgb.cv(params=params, train_set = cc_data,nfold=5, verbose_eval = 10, return_cvbooster=True, early_stopping_rounds= 100)
cc_time_taken = datetime.datetime.now() - cc_start
print(cc_time_taken)
# Out:
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:577: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# [LightGBM] [Info] Number of positive: 393, number of negative: 227452
# [LightGBM] [Info] [cross_entropy:Init]: (metric) labels passed interval [0, 1] check
# [LightGBM] [Info] [cross_entropy:Init]: sum-of-weights = 227845.000000
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.074360 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7650
# [LightGBM] [Info] Number of data points in the train set: 227845, number of used features: 30
# [LightGBM] [Info] [cross_entropy:Init]: (metric) labels passed interval [0, 1] check
# [LightGBM] [Info] [cross_entropy:Init]: sum-of-weights = 56962.000000
# [LightGBM] [Info] Number of positive: 393, number of negative: 227452
# [LightGBM] [Info] [cross_entropy:Init]: (metric) labels passed interval [0, 1] check
# [LightGBM] [Info] [cross_entropy:Init]: sum-of-weights = 227845.000000
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.074899 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7650
# [LightGBM] [Info] Number of data points in the train set: 227845, number of used features: 30
# [LightGBM] [Info] [cross_entropy:Init]: (metric) labels passed interval [0, 1] check
# [LightGBM] [Info] [cross_entropy:Init]: sum-of-weights = 56962.000000
# [LightGBM] [Info] Number of positive: 394, number of negative: 227452
# [LightGBM] [Info] [cross_entropy:Init]: (metric) labels passed interval [0, 1] check
# [LightGBM] [Info] [cross_entropy:Init]: sum-of-weights = 227846.000000
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.074579 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7650
# [LightGBM] [Info] Number of data points in the train set: 227846, number of used features: 30
# [LightGBM] [Info] [cross_entropy:Init]: (metric) labels passed interval [0, 1] check
# [LightGBM] [Info] [cross_entropy:Init]: sum-of-weights = 56961.000000
# [LightGBM] [Info] Number of positive: 394, number of negative: 227452
# [LightGBM] [Info] [cross_entropy:Init]: (metric) labels passed interval [0, 1] check
# [LightGBM] [Info] [cross_entropy:Init]: sum-of-weights = 227846.000000
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.081868 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7650
# [LightGBM] [Info] Number of data points in the train set: 227846, number of used features: 30
# [LightGBM] [Info] [cross_entropy:Init]: (metric) labels passed interval [0, 1] check
# [LightGBM] [Info] [cross_entropy:Init]: sum-of-weights = 56961.000000
# [LightGBM] [Info] Number of positive: 394, number of negative: 227452
# [LightGBM] [Info] [cross_entropy:Init]: (metric) labels passed interval [0, 1] check
# [LightGBM] [Info] [cross_entropy:Init]: sum-of-weights = 227846.000000
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.073962 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7650
# [LightGBM] [Info] Number of data points in the train set: 227846, number of used features: 30
# [LightGBM] [Info] [cross_entropy:Init]: (metric) labels passed interval [0, 1] check
# [LightGBM] [Info] [cross_entropy:Init]: sum-of-weights = 56961.000000
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.001725 -> initscore=-6.360885
# [LightGBM] [Info] Start training from score -6.360885
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.001725 -> initscore=-6.360885
# [LightGBM] [Info] Start training from score -6.360885
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.001729 -> initscore=-6.358344
# [LightGBM] [Info] Start training from score -6.358344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.001729 -> initscore=-6.358344
# [LightGBM] [Info] Start training from score -6.358344
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:620: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.001729 -> initscore=-6.358344
# [LightGBM] [Info] Start training from score -6.358344
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [10]	cv_agg's auc: 0.922736 + 0.0278212	cv_agg's cross_entropy: 0.633141 + 0.318649	cv_agg's l2: 0.0247395 + 0.0121967
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [20]	cv_agg's auc: 0.928314 + 0.01686	cv_agg's cross_entropy: 0.648176 + 0.123587	cv_agg's l2: 0.0282438 + 0.00397796
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [30]	cv_agg's auc: 0.934345 + 0.0153228	cv_agg's cross_entropy: 0.596831 + 0.145142	cv_agg's l2: 0.0249607 + 0.00511037
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [40]	cv_agg's auc: 0.915962 + 0.0121748	cv_agg's cross_entropy: 0.664768 + 0.210615	cv_agg's l2: 0.0271095 + 0.00708526
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [50]	cv_agg's auc: 0.921098 + 0.0154862	cv_agg's cross_entropy: 0.72792 + 0.15334	cv_agg's l2: 0.0305358 + 0.00455112
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [60]	cv_agg's auc: 0.826001 + 0.169724	cv_agg's cross_entropy: 0.755782 + 0.132616	cv_agg's l2: 0.0313731 + 0.00402272
# [70]	cv_agg's auc: 0.887872 + 0.0345232	cv_agg's cross_entropy: 1.03941 + 0.192447	cv_agg's l2: 0.0411843 + 0.00646205
# [80]	cv_agg's auc: 0.907956 + 0.0277944	cv_agg's cross_entropy: 0.97067 + 0.277464	cv_agg's l2: 0.0408523 + 0.0129177
# [90]	cv_agg's auc: 0.913748 + 0.0247482	cv_agg's cross_entropy: 1.05092 + 0.363701	cv_agg's l2: 0.0422334 + 0.0122375
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [100]	cv_agg's auc: 0.910529 + 0.0151656	cv_agg's cross_entropy: 1.02577 + 0.302063	cv_agg's l2: 0.039616 + 0.0101343
# 0:00:21.298477

# %%
cc_fi = getfeatureimpt(cc_eval)
cc_fi.head()
# Out:
#              mean      perc
# V17  2.487074e+11  0.311300
# V10  2.005616e+11  0.251037
# V18  8.958441e+10  0.112130
# V21  8.219796e+10  0.102885
# V3   5.999134e+10  0.075089

# %%
#best score
cc_eval['auc-mean'][-1]
# Out:
# 0.9373038335116363

# %%
# train time 
print(cc_time_taken)
# Out:
# 0:00:21.298477

# %% [markdown]
# ## XGBoost on Credit Card Data

# %% [markdown]
# ### Download Data

# %%
# !gdown --id 1tWqDuPaoKRiBiPJTi-jG5uP17AVrgzyc
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1tWqDuPaoKRiBiPJTi-jG5uP17AVrgzyc
# To: /content/creditcard.csv
# 100% 151M/151M [00:01<00:00, 141MB/s]

# %%
df_cc = pd.read_csv('creditcard.csv')
df_cc.head()
# Out:
#    Time        V1        V2        V3  ...       V27       V28  Amount  Class
# 0   0.0 -1.359807 -0.072781  2.536347  ...  0.133558 -0.021053  149.62      0
# 1   0.0  1.191857  0.266151  0.166480  ... -0.008983  0.014724    2.69      0
# 2   1.0 -1.358354 -1.340163  1.773209  ... -0.055353 -0.059752  378.66      0
# 3   1.0 -0.966272 -0.185226  1.792993  ...  0.062723  0.061458  123.50      0
# 4   2.0 -1.158233  0.877737  1.548718  ...  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %% [markdown]
# ### Data Preprocessing

# %%
df_cc_X = df_cc.drop('Class', axis = 1)
df_cc_X.head()
# Out:
#    Time        V1        V2        V3  ...       V26       V27       V28  Amount
# 0   0.0 -1.359807 -0.072781  2.536347  ... -0.189115  0.133558 -0.021053  149.62
# 1   0.0  1.191857  0.266151  0.166480  ...  0.125895 -0.008983  0.014724    2.69
# 2   1.0 -1.358354 -1.340163  1.773209  ... -0.139097 -0.055353 -0.059752  378.66
# 3   1.0 -0.966272 -0.185226  1.792993  ... -0.221929  0.062723  0.061458  123.50
# 4   2.0 -1.158233  0.877737  1.548718  ...  0.502292  0.219422  0.215153   69.99
#
# [5 rows x 30 columns]

# %%
x_train_cc, x_val_cc, y_train_cc, y_val_cc = train_test_split(df_cc_X, df_cc['Class'], test_size=0.33, random_state=42)

# %% [markdown]
# ### Run XGBoost

# %%
xgbmodel_cc = XGBClassifier(objective='binary:logistic',  n_estimators = 1000, booster = 'gbtree', eval_metric = ['auc', 'logloss'])
start = datetime.datetime.now()
xgbmodel_cc.fit(x_train_cc.values, y_train_cc.values, eval_set = [(x_val_cc.values, y_val_cc.values)], early_stopping_rounds = 20)
time_taken = datetime.datetime.now() - start
print(time_taken)
# Out:
# [0]	validation_0-auc:0.919213	validation_0-logloss:0.598059
# Multiple eval metrics have been passed: 'validation_0-logloss' will be used for early stopping.
#
# Will train until validation_0-logloss hasn't improved in 20 rounds.
# [1]	validation_0-auc:0.919237	validation_0-logloss:0.520193
# [2]	validation_0-auc:0.919255	validation_0-logloss:0.456273
# [3]	validation_0-auc:0.925971	validation_0-logloss:0.401311
# [4]	validation_0-auc:0.925977	validation_0-logloss:0.354323
# [5]	validation_0-auc:0.925974	validation_0-logloss:0.314671
# [6]	validation_0-auc:0.925958	validation_0-logloss:0.279634
# [7]	validation_0-auc:0.929317	validation_0-logloss:0.248951
# [8]	validation_0-auc:0.929308	validation_0-logloss:0.22228
# [9]	validation_0-auc:0.932646	validation_0-logloss:0.198931
# [10]	validation_0-auc:0.932647	validation_0-logloss:0.178033
# [11]	validation_0-auc:0.93265	validation_0-logloss:0.159589
# [12]	validation_0-auc:0.932676	validation_0-logloss:0.143505
# [13]	validation_0-auc:0.932681	validation_0-logloss:0.129034
# [14]	validation_0-auc:0.932684	validation_0-logloss:0.116075
# [15]	validation_0-auc:0.932691	validation_0-logloss:0.104623
# [16]	validation_0-auc:0.932693	validation_0-logloss:0.094107
# [17]	validation_0-auc:0.932692	validation_0-logloss:0.085108
# [18]	validation_0-auc:0.932693	validation_0-logloss:0.07682
# [19]	validation_0-auc:0.932693	validation_0-logloss:0.069293
# [20]	validation_0-auc:0.932688	validation_0-logloss:0.062704
# [21]	validation_0-auc:0.932691	validation_0-logloss:0.056683
# [22]	validation_0-auc:0.932697	validation_0-logloss:0.05132
# [23]	validation_0-auc:0.932701	validation_0-logloss:0.046504
# [24]	validation_0-auc:0.932677	validation_0-logloss:0.042151
# [25]	validation_0-auc:0.932642	validation_0-logloss:0.038261
# [26]	validation_0-auc:0.932488	validation_0-logloss:0.034693
# [27]	validation_0-auc:0.932489	validation_0-logloss:0.031546
# [28]	validation_0-auc:0.932489	validation_0-logloss:0.028663
# [29]	validation_0-auc:0.932461	validation_0-logloss:0.026121
# [30]	validation_0-auc:0.935754	validation_0-logloss:0.023745
# [31]	validation_0-auc:0.935773	validation_0-logloss:0.021662
# [32]	validation_0-auc:0.935779	validation_0-logloss:0.019754
# [33]	validation_0-auc:0.935778	validation_0-logloss:0.018059
# [34]	validation_0-auc:0.956328	validation_0-logloss:0.0165
# [35]	validation_0-auc:0.956309	validation_0-logloss:0.015132
# [36]	validation_0-auc:0.956309	validation_0-logloss:0.013857
# [37]	validation_0-auc:0.95631	validation_0-logloss:0.012733
# [38]	validation_0-auc:0.957945	validation_0-logloss:0.011711
# [39]	validation_0-auc:0.960534	validation_0-logloss:0.01077
# [40]	validation_0-auc:0.960243	validation_0-logloss:0.009934
# [41]	validation_0-auc:0.960242	validation_0-logloss:0.009193
# [42]	validation_0-auc:0.960158	validation_0-logloss:0.008501
# [43]	validation_0-auc:0.960219	validation_0-logloss:0.007898
# [44]	validation_0-auc:0.959995	validation_0-logloss:0.007334
# [45]	validation_0-auc:0.960164	validation_0-logloss:0.006835
# [46]	validation_0-auc:0.963342	validation_0-logloss:0.006379
# [47]	validation_0-auc:0.963292	validation_0-logloss:0.00597
# [48]	validation_0-auc:0.965925	validation_0-logloss:0.005598
# [49]	validation_0-auc:0.966619	validation_0-logloss:0.005274
# [50]	validation_0-auc:0.967004	validation_0-logloss:0.004968
# [51]	validation_0-auc:0.967067	validation_0-logloss:0.004706
# [52]	validation_0-auc:0.967191	validation_0-logloss:0.004449
# [53]	validation_0-auc:0.967138	validation_0-logloss:0.004232
# [54]	validation_0-auc:0.967151	validation_0-logloss:0.004036
# [55]	validation_0-auc:0.966704	validation_0-logloss:0.003849
# [56]	validation_0-auc:0.965329	validation_0-logloss:0.003694
# [57]	validation_0-auc:0.965439	validation_0-logloss:0.003547
# [58]	validation_0-auc:0.965854	validation_0-logloss:0.003414
# [59]	validation_0-auc:0.96591	validation_0-logloss:0.0033
# [60]	validation_0-auc:0.965361	validation_0-logloss:0.003193
# [61]	validation_0-auc:0.965294	validation_0-logloss:0.003098
# [62]	validation_0-auc:0.965267	validation_0-logloss:0.003012
# [63]	validation_0-auc:0.965296	validation_0-logloss:0.002933
# [64]	validation_0-auc:0.970291	validation_0-logloss:0.002859
# [65]	validation_0-auc:0.970338	validation_0-logloss:0.0028
# [66]	validation_0-auc:0.973816	validation_0-logloss:0.00274
# [67]	validation_0-auc:0.973774	validation_0-logloss:0.00269
# [68]	validation_0-auc:0.973829	validation_0-logloss:0.002644
# [69]	validation_0-auc:0.973304	validation_0-logloss:0.002598
# [70]	validation_0-auc:0.973422	validation_0-logloss:0.002562
# [71]	validation_0-auc:0.97353	validation_0-logloss:0.002527
# [72]	validation_0-auc:0.976381	validation_0-logloss:0.002496
# [73]	validation_0-auc:0.976057	validation_0-logloss:0.002469
# [74]	validation_0-auc:0.976336	validation_0-logloss:0.002441
# [75]	validation_0-auc:0.976962	validation_0-logloss:0.00242
# [76]	validation_0-auc:0.9796	validation_0-logloss:0.002398
# [77]	validation_0-auc:0.978311	validation_0-logloss:0.00238
# [78]	validation_0-auc:0.979212	validation_0-logloss:0.002359
# [79]	validation_0-auc:0.978689	validation_0-logloss:0.00234
# [80]	validation_0-auc:0.978026	validation_0-logloss:0.002324
# [81]	validation_0-auc:0.978711	validation_0-logloss:0.002311
# [82]	validation_0-auc:0.977817	validation_0-logloss:0.002304
# [83]	validation_0-auc:0.978381	validation_0-logloss:0.002293
# [84]	validation_0-auc:0.977432	validation_0-logloss:0.002284
# [85]	validation_0-auc:0.978752	validation_0-logloss:0.002277
# [86]	validation_0-auc:0.978233	validation_0-logloss:0.002266
# [87]	validation_0-auc:0.978337	validation_0-logloss:0.002261
# [88]	validation_0-auc:0.978209	validation_0-logloss:0.002254
# [89]	validation_0-auc:0.97873	validation_0-logloss:0.002247
# [90]	validation_0-auc:0.978775	validation_0-logloss:0.002246
# [91]	validation_0-auc:0.979024	validation_0-logloss:0.002237
# [92]	validation_0-auc:0.979335	validation_0-logloss:0.002232
# [93]	validation_0-auc:0.978727	validation_0-logloss:0.002229
# [94]	validation_0-auc:0.979091	validation_0-logloss:0.00222
# [95]	validation_0-auc:0.979894	validation_0-logloss:0.00221
# [96]	validation_0-auc:0.979836	validation_0-logloss:0.002208
# [97]	validation_0-auc:0.980451	validation_0-logloss:0.002206
# [98]	validation_0-auc:0.981027	validation_0-logloss:0.002196
# [99]	validation_0-auc:0.981137	validation_0-logloss:0.002195
# [100]	validation_0-auc:0.980855	validation_0-logloss:0.002195
# [101]	validation_0-auc:0.980756	validation_0-logloss:0.002192
# [102]	validation_0-auc:0.981162	validation_0-logloss:0.002188
# [103]	validation_0-auc:0.981336	validation_0-logloss:0.002189
# [104]	validation_0-auc:0.981543	validation_0-logloss:0.002188
# [105]	validation_0-auc:0.981486	validation_0-logloss:0.002185
# [106]	validation_0-auc:0.981502	validation_0-logloss:0.002184
# [107]	validation_0-auc:0.982012	validation_0-logloss:0.002177
# [108]	validation_0-auc:0.982034	validation_0-logloss:0.002175
# [109]	validation_0-auc:0.982216	validation_0-logloss:0.002171
# [110]	validation_0-auc:0.982557	validation_0-logloss:0.00217
# [111]	validation_0-auc:0.98271	validation_0-logloss:0.002166
# [112]	validation_0-auc:0.983151	validation_0-logloss:0.002163
# [113]	validation_0-auc:0.983319	validation_0-logloss:0.002156
# [114]	validation_0-auc:0.983712	validation_0-logloss:0.002144
# [115]	validation_0-auc:0.983698	validation_0-logloss:0.002141
# [116]	validation_0-auc:0.98362	validation_0-logloss:0.002142
# [117]	validation_0-auc:0.98381	validation_0-logloss:0.002141
# [118]	validation_0-auc:0.983745	validation_0-logloss:0.002141
# [119]	validation_0-auc:0.983802	validation_0-logloss:0.002139
# [120]	validation_0-auc:0.983692	validation_0-logloss:0.00214
# [121]	validation_0-auc:0.983346	validation_0-logloss:0.002144
# [122]	validation_0-auc:0.983331	validation_0-logloss:0.002142
# [123]	validation_0-auc:0.983384	validation_0-logloss:0.002141
# [124]	validation_0-auc:0.983069	validation_0-logloss:0.002139
# [125]	validation_0-auc:0.983078	validation_0-logloss:0.002141
# [126]	validation_0-auc:0.982949	validation_0-logloss:0.00214
# [127]	validation_0-auc:0.983219	validation_0-logloss:0.002139
# [128]	validation_0-auc:0.982903	validation_0-logloss:0.002142
# [129]	validation_0-auc:0.982907	validation_0-logloss:0.00214
# [130]	validation_0-auc:0.983028	validation_0-logloss:0.002138
# [131]	validation_0-auc:0.983134	validation_0-logloss:0.002132
# [132]	validation_0-auc:0.983193	validation_0-logloss:0.002132
# [133]	validation_0-auc:0.983265	validation_0-logloss:0.002132
# [134]	validation_0-auc:0.983273	validation_0-logloss:0.002128
# [135]	validation_0-auc:0.983439	validation_0-logloss:0.002124
# [136]	validation_0-auc:0.983087	validation_0-logloss:0.002125
# [137]	validation_0-auc:0.983183	validation_0-logloss:0.002124
# [138]	validation_0-auc:0.983007	validation_0-logloss:0.002123
# [139]	validation_0-auc:0.982879	validation_0-logloss:0.002125
# [140]	validation_0-auc:0.98268	validation_0-logloss:0.002126
# [141]	validation_0-auc:0.982953	validation_0-logloss:0.002124
# [142]	validation_0-auc:0.983083	validation_0-logloss:0.002122
# [143]	validation_0-auc:0.983056	validation_0-logloss:0.00212
# [144]	validation_0-auc:0.982518	validation_0-logloss:0.002122
# [145]	validation_0-auc:0.982294	validation_0-logloss:0.002123
# [146]	validation_0-auc:0.982439	validation_0-logloss:0.002121
# [147]	validation_0-auc:0.982242	validation_0-logloss:0.002123
# [148]	validation_0-auc:0.982124	validation_0-logloss:0.002123
# [149]	validation_0-auc:0.982139	validation_0-logloss:0.002117
# [150]	validation_0-auc:0.982069	validation_0-logloss:0.002117
# [151]	validation_0-auc:0.98167	validation_0-logloss:0.002116
# [152]	validation_0-auc:0.981674	validation_0-logloss:0.002115
# [153]	validation_0-auc:0.981703	validation_0-logloss:0.002112
# [154]	validation_0-auc:0.982027	validation_0-logloss:0.002109
# [155]	validation_0-auc:0.982147	validation_0-logloss:0.002108
# [156]	validation_0-auc:0.981999	validation_0-logloss:0.002105
# [157]	validation_0-auc:0.981608	validation_0-logloss:0.002104
# [158]	validation_0-auc:0.981804	validation_0-logloss:0.0021
# [159]	validation_0-auc:0.981787	validation_0-logloss:0.002096
# [160]	validation_0-auc:0.98166	validation_0-logloss:0.002097
# [161]	validation_0-auc:0.981656	validation_0-logloss:0.002097
# [162]	validation_0-auc:0.981399	validation_0-logloss:0.002099
# [163]	validation_0-auc:0.981433	validation_0-logloss:0.002099
# [164]	validation_0-auc:0.981371	validation_0-logloss:0.002102
# [165]	validation_0-auc:0.981192	validation_0-logloss:0.002097
# [166]	validation_0-auc:0.981332	validation_0-logloss:0.002097
# [167]	validation_0-auc:0.981409	validation_0-logloss:0.002095
# [168]	validation_0-auc:0.981163	validation_0-logloss:0.002097
# [169]	validation_0-auc:0.981148	validation_0-logloss:0.002096
# [170]	validation_0-auc:0.981311	validation_0-logloss:0.002095
# [171]	validation_0-auc:0.981387	validation_0-logloss:0.002094
# [172]	validation_0-auc:0.981439	validation_0-logloss:0.002091
# [173]	validation_0-auc:0.981213	validation_0-logloss:0.002093
# [174]	validation_0-auc:0.981243	validation_0-logloss:0.002093
# [175]	validation_0-auc:0.981775	validation_0-logloss:0.002086
# [176]	validation_0-auc:0.981756	validation_0-logloss:0.002087
# [177]	validation_0-auc:0.981775	validation_0-logloss:0.002083
# [178]	validation_0-auc:0.981814	validation_0-logloss:0.002084
# [179]	validation_0-auc:0.981694	validation_0-logloss:0.002082
# [180]	validation_0-auc:0.98155	validation_0-logloss:0.002085
# [181]	validation_0-auc:0.981551	validation_0-logloss:0.002086
# [182]	validation_0-auc:0.981702	validation_0-logloss:0.002084
# [183]	validation_0-auc:0.981922	validation_0-logloss:0.002082
# [184]	validation_0-auc:0.981856	validation_0-logloss:0.002081
# [185]	validation_0-auc:0.981803	validation_0-logloss:0.00208
# [186]	validation_0-auc:0.981674	validation_0-logloss:0.002081
# [187]	validation_0-auc:0.981666	validation_0-logloss:0.00208
# [188]	validation_0-auc:0.981714	validation_0-logloss:0.002079
# [189]	validation_0-auc:0.981828	validation_0-logloss:0.002078
# [190]	validation_0-auc:0.98208	validation_0-logloss:0.002074
# [191]	validation_0-auc:0.982129	validation_0-logloss:0.002074
# [192]	validation_0-auc:0.981956	validation_0-logloss:0.002071
# [193]	validation_0-auc:0.981974	validation_0-logloss:0.002071
# [194]	validation_0-auc:0.981991	validation_0-logloss:0.00207
# [195]	validation_0-auc:0.981749	validation_0-logloss:0.002073
# [196]	validation_0-auc:0.981521	validation_0-logloss:0.002076
# [197]	validation_0-auc:0.981599	validation_0-logloss:0.002075
# [198]	validation_0-auc:0.981561	validation_0-logloss:0.002075
# [199]	validation_0-auc:0.98158	validation_0-logloss:0.002076
# [200]	validation_0-auc:0.98164	validation_0-logloss:0.002073
# [201]	validation_0-auc:0.98168	validation_0-logloss:0.002072
# [202]	validation_0-auc:0.981802	validation_0-logloss:0.002069
# [203]	validation_0-auc:0.981928	validation_0-logloss:0.002066
# [204]	validation_0-auc:0.981976	validation_0-logloss:0.002067
# [205]	validation_0-auc:0.981964	validation_0-logloss:0.002066
# [206]	validation_0-auc:0.981935	validation_0-logloss:0.002066
# [207]	validation_0-auc:0.982177	validation_0-logloss:0.002058
# [208]	validation_0-auc:0.982237	validation_0-logloss:0.00206
# [209]	validation_0-auc:0.982248	validation_0-logloss:0.00206
# [210]	validation_0-auc:0.982286	validation_0-logloss:0.00206
# [211]	validation_0-auc:0.98223	validation_0-logloss:0.00206
# [212]	validation_0-auc:0.982062	validation_0-logloss:0.002062
# [213]	validation_0-auc:0.982058	validation_0-logloss:0.002061
# [214]	validation_0-auc:0.981889	validation_0-logloss:0.002061
# [215]	validation_0-auc:0.981794	validation_0-logloss:0.002065
# [216]	validation_0-auc:0.981667	validation_0-logloss:0.002067
# [217]	validation_0-auc:0.981755	validation_0-logloss:0.002065
# [218]	validation_0-auc:0.981776	validation_0-logloss:0.002067
# [219]	validation_0-auc:0.98192	validation_0-logloss:0.002063
# [220]	validation_0-auc:0.98196	validation_0-logloss:0.002062
# [221]	validation_0-auc:0.982018	validation_0-logloss:0.002062
# [222]	validation_0-auc:0.982129	validation_0-logloss:0.002059
# [223]	validation_0-auc:0.982107	validation_0-logloss:0.00206
# [224]	validation_0-auc:0.982216	validation_0-logloss:0.002058
# [225]	validation_0-auc:0.982198	validation_0-logloss:0.002061
# [226]	validation_0-auc:0.982245	validation_0-logloss:0.00206
# [227]	validation_0-auc:0.982348	validation_0-logloss:0.002054
# [228]	validation_0-auc:0.982197	validation_0-logloss:0.002056
# [229]	validation_0-auc:0.982061	validation_0-logloss:0.002059
# [230]	validation_0-auc:0.982054	validation_0-logloss:0.00206
# [231]	validation_0-auc:0.982061	validation_0-logloss:0.00206
# [232]	validation_0-auc:0.981893	validation_0-logloss:0.002063
# [233]	validation_0-auc:0.981779	validation_0-logloss:0.002061
# [234]	validation_0-auc:0.981881	validation_0-logloss:0.002059
# [235]	validation_0-auc:0.98183	validation_0-logloss:0.002057
# [236]	validation_0-auc:0.981901	validation_0-logloss:0.002058
# [237]	validation_0-auc:0.981853	validation_0-logloss:0.002061
# [238]	validation_0-auc:0.982016	validation_0-logloss:0.002062
# [239]	validation_0-auc:0.981958	validation_0-logloss:0.002064
# [240]	validation_0-auc:0.982058	validation_0-logloss:0.002064
# [241]	validation_0-auc:0.982051	validation_0-logloss:0.002063
# [242]	validation_0-auc:0.981938	validation_0-logloss:0.002065
# [243]	validation_0-auc:0.981925	validation_0-logloss:0.002065
# [244]	validation_0-auc:0.981863	validation_0-logloss:0.002067
# [245]	validation_0-auc:0.98196	validation_0-logloss:0.002066
# [246]	validation_0-auc:0.981862	validation_0-logloss:0.002068
# [247]	validation_0-auc:0.981762	validation_0-logloss:0.002067
# Stopping. Best iteration:
# [227]	validation_0-auc:0.982348	validation_0-logloss:0.002054
#
# 0:02:06.452879

# %% [markdown]
# ### Feature Importance

# %%
mean_dict_cc = {}
counter = 0
fi_array_cc = xgbmodel_cc.get_booster().get_score(importance_type = 'gain')

for col in df_cc_X.columns:
  mean_dict_cc[col] = fi_array_cc['f'+str(counter)]
  counter += 1

fi_dict_cc = {}
fi_dict_cc['mean'] = mean_dict_cc
fi_df_cc = pd.DataFrame(fi_dict_cc, index=df_cc_X.columns)
fi_df_cc['perc'] = fi_df_cc['mean']/fi_df_cc['mean'].sum()

# %%
fi_df_cc.sort_values(by = 'perc', ascending = False)
# Out:
#              mean      perc
# V17     51.822475  0.251742
# V14     24.218101  0.117646
# V10     10.367123  0.050361
# V7       8.612096  0.041836
# V4       7.358882  0.035748
# V1       6.874751  0.033396
# V20      5.604944  0.027228
# V21      5.519701  0.026814
# V28      5.478786  0.026615
# V12      5.386324  0.026166
# V27      5.106954  0.024808
# Amount   5.066545  0.024612
# V8       4.862705  0.023622
# V26      4.467243  0.021701
# V5       4.366278  0.021210
# V16      4.224569  0.020522
# V9       4.107097  0.019951
# V15      4.053486  0.019691
# V6       3.986082  0.019364
# V19      3.984774  0.019357
# V2       3.956697  0.019221
# V25      3.396037  0.016497
# V23      3.192786  0.015510
# V24      3.070598  0.014916
# V13      2.908488  0.014129
# V11      2.905909  0.014116
# V22      2.893119  0.014054
# V3       2.760006  0.013408
# Time     2.694577  0.013090
# V18      2.608047  0.012669
